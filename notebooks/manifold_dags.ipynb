# %%
import networkx as nx
import numpy as np
from matplotlib import pyplot as plt

# %%
G = nx.DiGraph()
G.add_edges_from(
    [
        ("Engagement", "Prior"),
        ("Prior", "Manifold"),
        ("Engagement", "Manifold"),
        ("Prior", "Decision"),
        ("Stimulus", "Decision"),
        ("Manifold", "Decision"),
    ]
)

# %%
pos = nx.spring_layout(G)
fig, ax = plt.subplots(figsize=(8, 8))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_color="lightblue",
    node_size=5000,
    font_size=10,
    arrows=True,
)
plt.show()

# %%
nx.is_d_separator(G, {"Manifold"}, {"Stimulus"}, set())
# Out:
# True

# %%
for node in ["Engagement", "Prior"]:
    sep = nx.is_d_separator(G, {"Decision"}, {"Manifold"}, {node})
    print(f"Is it safe to condition on {node}? {sep}")
# Out:
# Is it safe to condition on Engagement? False
# Is it safe to condition on Prior? False
